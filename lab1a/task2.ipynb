# %% [markdown]
# # Task 2: Classification with a single-layer perceptron and analysis

# %%
from tools import PerceptronClassifier, get_linearly_separable_dataset, plot_decision_boundary
import numpy as np

classifier = PerceptronClassifier()

data, labels = get_linearly_separable_dataset()

classifier.fit(data, labels, epochs=100)

predictions = classifier.predict(data)

# %%
plot_decision_boundary(classifier.weights, data, labels, "Perceptron Decision Boundary")
# Out:
# [-84.7357542] [141.06070902] [7.48621312]
# (100,) (100,)
# [[-84.7357542 ]
#  [141.06070902]
#  [  7.48621312]]
