# %% [markdown]
# # Task 2: Classification with a single-layer perceptron and analysis

# %%
from tools import PerceptronClassifier, generate_dataset, plot_decision_boundary

classifier = PerceptronClassifier()

data, labels = generate_dataset()

classifier.fit(data, labels, epochs=20)

predictions = classifier.predict(data)

# %%
plot_decision_boundary(classifier.weights, data, labels, "Perceptron Decision Boundary")

# %%
from tools import DeltaRuleClassifier
import numpy as np

classifier = DeltaRuleClassifier()

data, labels = generate_dataset()
labels = np.where(labels == 0, -1, 1)

classifier.fit(data, labels, epochs=100)

predictions = classifier.predict(data)

# %%
plot_decision_boundary(classifier.weights, data, labels, "Delta Rule Decision Boundary")
